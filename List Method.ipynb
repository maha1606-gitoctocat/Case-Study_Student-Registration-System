# %% [markdown]
# <a href="https://colab.research.google.com/github/maha1606-gitoctocat/Case-Study/blob/main/Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Case Study – Shopping Cart System**
# **Instructions:**
# 1. Create a list named `cart` with initial items:
#    Milk, Bread, Eggs, Apple
# 2. Perform list operations:
#  • Add multiple items using extend()
#  • Insert item at index 2 using insert()
#  • Remove item Apple using remove()
#  • Remove last item using pop()
# 3. Use list methods:
#    • index() to find position of Eggs
#    • count() to count occurrences of Milk
# 4. Apply indexing:
#    • Display first item
#    • Display last item
# 5. Apply slicing:
#    • Display first 3 items from the list
# 6. Find total number of items using len()
# 7. Display all outputs using print()

# %%
# Cart Details
Cart = ["Milk", "Bread", "Eggs", "Apple"]

# Add
Cart.extend(["Butter", "Curd"])

# Insert
Cart.insert(2, "Cheese")

# Remove
Cart.remove("Apple")

# Pop
Cart.pop()

# Index
EggsIndex = Cart.index("Eggs")

# Count
MilkCount = Cart.count("Milk")

# Display first item
Cart[0]

# Display last item
Cart[3]

# Display First 3 items
Cart[0:3]

# Total Number of items
len(Cart)

# Print all outputs
print(f"Cart: {Cart}")
print(f"Eggs Index: {EggsIndex}")
print(f"Milk Count: {MilkCount}")
print(f"Total Items: {len(Cart)}")
# Out:
# Cart: ['Milk', 'Bread', 'Cheese', 'Eggs', 'Butter']
# Eggs Index: 3
# Milk Count: 1
# Total Items: 5
