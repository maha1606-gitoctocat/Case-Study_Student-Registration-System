# %% [markdown]
# <a href="https://colab.research.google.com/github/maha1606-gitoctocat/Case-Study/blob/main/Operators_and_Control_Statement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Age = int(input("Enter the Age: "))
Citizenship= input("Enter the Citizenship: ")

if Age >=18:
  if Citizenship == "India":
    print("Yes your are eligible to vote")
  else:
    print("Not a citizen no eligible")
else:
  print("Not Eligible")
# Out:
# Enter the Age: 20
# Enter the Citizenship: India
# Yes your are eligible to vote

# %%
Number = int(input("Enter the Number: "))

if Number %2 ==0 :
  print("Even Number")
else:
  print("Odd Number")
# Out:
# Enter the Number: 9
# Odd Number

# %%
Letter = input("Enter the Letter: ").lower()

if Letter in "aeiou":
  print("Vowel")
else:
  print("Consonant")
# Out:
# Enter the Letter: a
# Vowel

# %%
Mark = int(input("Enter the Mark: "))

if Mark >=90:
  print("Grade A")
elif Mark >=80:
  print("Grade B")
elif Mark >=70:
  print("Grade C")
elif Mark >=60:
  print("Grade D")
else:
  print("Fail")
# Out:
# Enter the Mark: 50
# Fail

# %%
# Customer Data
Name = "Mahalakshmi"
Age = 23
Income = 50000
Credit_Score = 734
existing_loan = False

# Loan eligibility check
if Age >=21 and Income >=40000:
  if Credit_Score >= 700 and not existing_loan:
    Status = "Approved"
  elif Credit_Score >= 650 and not existing_loan:
    Status = "Conditionally Approved"
  else:
    Status = "Rejected"
else:
  Status = "Not Eligible"
print(f"Loan Status: {Status}")
# Out:
# Loan Status: Approved

# %% [markdown]
# Case Study Scholarship Eligibility Checker
# Instructions:
#
# Create variables: student_name, marks, attendance, family_income.
#
# Use conditional statements (if, elif, else) to:
#
# Award Full Scholarship if marks ≥ 90 and attendance ≥ 90.
# Award Half Scholarship if marks ≥ 80 or attendance ≥ 85.
# Award Need-Based Scholarship if marks ≥ 70 and family_income < 30000.
# Otherwise, display Not Eligible.
# Display all data (no loops).

# %%
# Scholarship Eligibility Check
Student_name = "Mahalakshmi"
Marks = 90
Attendance = 90
Family_income = 50000

if Family_income >= 30000:
  if Marks >= 90 and Attendance >= 90:
    Scholarship = "Full Scholarship"
  elif Marks >= 80 or Attendance >= 85:
    Scholarship = "Half Scholarship"
  elif Marks >= 70 and Attendance >=70:
    Scholarship = "Need-Based Scholarship"
else:
  Scholarship = "Not Eligible"
print(f"Scholarship Status: {Scholarship}")
# Out:
# Scholarship Status: Full Scholarship
