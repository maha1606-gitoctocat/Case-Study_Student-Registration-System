# %% [markdown]
# <a href="https://colab.research.google.com/github/maha1606-gitoctocat/Case-Study_Student-Registration-System/blob/main/Case_Study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Registration System

# Taking Input From User
Student_Name = input("Enter Student Name: ")
Student_Age = int(input("Enter Student Age: "))
Course_Name = input("Enter Course Name: ")
Course_Fee = int(input("Enter Course Fee: "))

# GST Calculation

GST = Course_Fee * 0.18
Total_Fee = Course_Fee + GST

# Displaying Students Details
print("\n-----Students Details-----")

print(f"Student Name: {Student_Name}")
print(f"Student Age: {Student_Age}")
print(f"Course Name: {Course_Name}")

print("\n-----Fee Details-----")

print(f"GST Amount : {GST}")
print(f"Total Fee : {Total_Fee} ")

#Displaying Datatypes
print("\n-----Datatypes-----")

print(type(Student_Name))
print(type(Student_Age))
print(type(Course_Fee))
# Out:
# Enter Student Name: Mahalakshmi
# Enter Student Age: 23
# Enter Course Name: Data Analyst
# Enter Course Fee: 45000
#
# -----Students Details-----
# Student Name: Mahalakshmi
# Student Age: 23
# Course Name: Data Analyst
#
# -----Fee Details-----
# GST Amount : 8100.0
# Total Fee : 53100.0
#
# -----Datatypes-----
# <class 'str'>
# <class 'int'>
# <class 'int'>

# %%
#Library Fine Calculator

# Taking input from user
Student_Name = input("Enter Student Name: ")
Book_Name = input("Enter Book Name: ")
Days_Late = int(input("Enter Number of Days Late: "))
Fine_Per_Day = float(input("Enter Fine Per Day: "))

# Fine Calculation
Total_Fine = Days_Late * Fine_Per_Day

#Displaying Details
print("\n------Library Fine Details------")

print(f"Student Name: {Student_Name}")
print(f"Book Name: {Book_Name}")
print(f"Days Late: {Days_Late}")
print(f"Fine Per Day: {Fine_Per_Day}")
print(f"Total Fine: {Total_Fine}")

# Displaying Datatypes
print("\n------Datatypes-----")


print(type(Student_Name))
print(type(Days_Late))
print(type(Fine_Per_Day))
# Out:
# Enter Student Name: Mahalakshmi
# Enter Book Name: Maths Book
# Enter Number of Days Late: 3
# Enter Fine Per Day: 50
#
# ------Library Fine Details------
# Student Name: Mahalakshmi
# Book Name: Maths Book
# Days Late: 3
# Fine Per Day: 50.0
# Total Fine: 150.0
#
# ------Datatypes-----
# <class 'str'>
# <class 'int'>
# <class 'float'>
